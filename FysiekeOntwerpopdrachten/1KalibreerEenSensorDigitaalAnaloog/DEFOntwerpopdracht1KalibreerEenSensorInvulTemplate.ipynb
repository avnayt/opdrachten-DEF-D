# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
#
# | Groep: 33     |  |
# | :-------------|:-------------|
# | Avnay Taneja| 5938724 |
# | Erik van den Berkmortel | 6565182 |
# | Carsten Schroevers| 6126634|
#
# | Planning Groep: 33     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 11:30 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 14:00 |
# | Pauze 1| 15 min |
# | Pauze 2| 15 min |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
# ![Alt](ontwerpstap.jpeg "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |LDR |Zet een lamp aan wanneer er een andere lamp op schijnt (werkt alleen in het donker) | Werkt als de lichtintensiteit in de omgeving onder 100 lux is. Werkt als de lichtintensiteit van de andere lamp boven 300 lux is. Moet kunnen meten hoe sterk de lamp schijnt met foutmarge van 10 lux.|
# |Thermistor | Thermometer | Moet temperaturen van minimaal 10 graden tot maximaal 40 graden meten. Moet binnen 10 seconden de temperatuur meten. Bij een constante temperatuur mag de gemeten waarde niet meer dan 5 graden fluctueren gedurende 30 seconden.|
# |Indruksensor | Weegschaal | Moet minimaal massa's van 5 gram en maximaal massa's van 3 kilogram kunnen meten. Moet nauwkeurigheid hebben van 10%. Het kost maximaal 10 seconden voordat er een stabiele meetwaarde komt.|

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Op de afbeelding is een circuit verbonden met een arduino te zien, met daaraan een thermistor. Er is verder ook een plastic zakje te zien die om de thermistor gezet wordt wanneer die in water wordt gebracht.
#  ![Alt](schets_meetopstelling2.jpeg "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen? \
# De temperatuur.
# 2. Over welk bereik ga je deze variabelen veranderen?\
# 5 tot 50 graden.
# 3. Wat ga je allemaal meten?\
# De temperatuur in verschillende omgevingen (kamertemperatuur, buitenlucht, duim op thermistor, koelkast, zakje in water).
# 4. Hoeveel metingen ga je doen?\
# 15 metingen.
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?\
# Ja.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Een circuit vanuit een arduino met een breadboard waarop een thermistor is verbonden in serie met een 10 kilo-ohm weerstand en door de arduino wordt afgelezen.
#  ![Alt](meetopstelling.jpeg "meetopstelling student")

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
import numpy as np
array_temps = np.array([521, 510, 524, 728, 729, 732, 407, 422, 404, 690, 660, 680, 190, 182, 260])
array_control_temps = np.array([23.4, 23.6, 23.6, 4.5, 4.3, 4.1, 33.2, 31.5, 33.8, 4.7, 5.8, 5.2, 63.5, 65.3, 51.6])

x = np.array([499, 497, 508, 509, 504, 510, 488, 495, 506, 504]) #Metingen gedaan in zelfde omgeving (kamertemperatuur)

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def linear_model(x, a, b):
    return a*x + b

popt,pcov = curve_fit(linear_model,array_temps,array_control_temps)
a, b = popt

sigma_a = np.sqrt(pcov[0,0])
sigma_b = np.sqrt(pcov[1,1])

x_fit = np.linspace(100,900,1000)
y_fit = a*x_fit+b

y_fit_error = np.sqrt((x_fit*sigma_a)**2 + sigma_b**2)

plt.figure()
plt.plot(x_fit,y_fit)
plt.errorbar(array_temps,array_control_temps, xerr = sigma_a, yerr = sigma_b , fmt='.', label="fitfunctie")
plt.plot(array_temps,array_control_temps, 'k.', label='gemeten data')
plt.legend()
plt.xlim(100,900)
plt.ylim(-5,75)
plt.xlabel('Bits')
plt.ylabel('Controletemperatuur')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# De sensor is geschikt voor de gekozen toepassing, dus er wordt niet geïtereerd.

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# De sensor is bruikbaar voor de gekozen toepassing, aangezien het tussen 10 en 40 graden kan meten. Dit blijkt uit de grafiek aangezien er meetpunten onder de 10 graden en metingen boven de 40 graden zichtbaar zijn. Ook is er ondervonden dat er binnen een tijd van 10 seconden een stabiele meting uitkwam. Verder was er gedurende 30 seconden geen fluctuatie van meer dan 5 graden in de gemeten temperatuur.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# Op de afbeelding is een circuit verbonden met een arduino te zien, met daaraan een thermistor. Er is verder ook een plastic zakje te zien die om de thermistor gezet wordt wanneer die in water wordt gebracht.
#  ![Alt](schets_meetopstelling2.jpeg "schets student")
#
# Een circuit vanuit een arduino met een breadboard waarop een thermistor is verbonden in serie met een 10 kilo-ohm weerstand en door de arduino wordt afgelezen.
#  ![Alt](meetopstelling.jpeg "meetopstelling student")

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |LDR |Zet een lamp aan wanneer er een andere lamp op schijnt (werkt alleen in het donker) | Werkt als de lichtintensiteit in de omgeving onder 100 lux is. Werkt als de lichtintensiteit van de andere lamp boven 300 lux is. Moet kunnen meten hoe sterk de lamp schijnt met foutmarge van 10 lux.|
# |Thermistor | Thermometer | Moet temperaturen van minimaal 10 graden tot maximaal 40 graden meten. Moet binnen 10 seconden de temperatuur meten. Bij een constante temperatuur mag de gemeten waarde niet meer dan 5 graden fluctueren gedurende 30 seconden.|
# |Indruksensor | Weegschaal | Moet minimaal massa's van 5 gram en maximaal massa's van 3 kilogram kunnen meten. Moet nauwkeurigheid hebben van 10%. Het kost maximaal 10 seconden voordat er een stabiele meetwaarde komt.|

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# Een circuit vanuit een arduino met een breadboard waarop een thermistor is verbonden in serie met een 10 kilo-ohm weerstand en door de arduino wordt afgelezen.
#  ![Alt](meetopstelling.jpeg "meetopstelling student")

# %% [markdown]
# Conclusie:\
# De sensor is bruikbaar voor de gekozen toepassing, aangezien het tussen 10 en 40 graden kan meten. Dit blijkt uit de grafiek aangezien er meetpunten onder de 10 graden en metingen boven de 40 graden zichtbaar zijn. Ook is er ondervonden dat er binnen een tijd van 10 seconden een stabiele meting uitkwam. Verder was er gedurende 30 seconden geen fluctuatie van meer dan 5 graden in de gemeten temperatuur.

# %%
def linear_model(x, a, b):
    return a*x + b

popt,pcov = curve_fit(linear_model,array_temps,array_control_temps)
a, b = popt

sigma_a = np.sqrt(pcov[0,0])
sigma_b = np.sqrt(pcov[1,1])

x_fit = np.linspace(100,900,1000)
y_fit = a*x_fit+b

y_fit_error = np.sqrt((x_fit*sigma_a)**2 + sigma_b**2)

plt.figure()
plt.plot(x_fit,y_fit)
plt.errorbar(array_temps,array_control_temps, xerr = sigma_a, yerr = sigma_b , fmt='.', label="fitfunctie")
plt.plot(array_temps,array_control_temps, 'k.', label='gemeten data')
plt.legend()
plt.xlim(100,900)
plt.ylim(-5,75)
plt.xlabel('Bits')
plt.ylabel('Controletemperatuur')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
